# %% [markdown]
# # Plotting with Glyphs

# %% [markdown]
#  ### Typical usage

# %%
# %matplotlib inline
from bokeh.io import output_file, show

# %%
from bokeh.plotting import figure

# %%
plot = figure(plot_width=400, tools ='pan,box_zoom')

# %%
plot.circle([1,2,3,4,5,],[8,6,5,2,3])
output_file('circle.html')
show(plot)

# %% [markdown]
# ![20180524_184520.png](attachment:20180524_184520.png)

# %% [markdown]
# _ _

# %% [markdown]
# ### Glyph properties

# %% [markdown]
# - Lists, arrays, sequences of values
# - Single fixed values

# %%
plot = figure()
plot.circle(x=10, y=[2,5,8,10], size=[10,20,30,40])
show(plot)

# %% [markdown]
# ![20180524_184556.png](attachment:20180524_184556.png)

# %% [markdown]
# ### Lines

# %%
x = [1,2,3,4,5]
y = [8,6,5,2,3]
plot = figure()

# %%
plot.line(x,y,line_width = 3)
output_file('line.html')
show(plot)

# %% [markdown]
# ![20180524_184701.png](attachment:20180524_184701.png)

# %% [markdown]
# _ _

# %% [markdown]
# ### Lines and Markers Together

# %%
x = [1,2,3,4,5]
y = [8,6,5,2,3]
plot = figure()
plot.line(x,y, line_width=2)
plot.circle(x,y,fill_color='white',size=10)
output_file('line.html')
show(plot)

# %% [markdown]
# ![20180524_184751.png](attachment:20180524_184751.png)

# %% [markdown]
# _ _

# %% [markdown]
# ### Patches

# %% [markdown]
# Useful for showing geographic regions
#
# Data given as list of list

# %%
xs =[[1,1,2,2],[2,2,4],[2,2,3,3]]
ys =[[2,5,5,2],[3,5,5],[2,3,4,2]]
plot = figure()
plot.patches(xs,ys,
            fill_color=
            ['red','blue','green'],
            line_color ='white')
output_file('patches.html')
show(plot)

# %% [markdown]
# ![20180524_184842.png](attachment:20180524_184842.png)

# %% [markdown]
# _ _
